# %% [markdown]
# <a href="https://colab.research.google.com/github/cy643/generative_ai/blob/main/0506_hw11/0506_hw11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 0506_HW11 打造你的 Fooocus Workflow
# 設想一個應用情境，並使用 Fooocus 生成圖像
#
# ## 應用情境
# **個人品牌圖像**：打造一系列統一風格的插畫人物頭像，用於 Instagram、LinkedIn 和個人網站，提高品牌辨識度。
#
# ## 創作流程
# 1. **靈感來源**：希望呈現出一個「科技感 + 專業但親切」的風格，靈感來自 Notion、Raycast、Figma 等工具的官網風格，以及 Midjourney 常見的人像構圖。
#
# 2. **設定與嘗試**：
#
# - 初步設定 prompt：使用自然語言描述想像中的人物與背景。
#
# - 風格套用：測試不同風格模型（如插畫風、數位肖像、極簡 UI 插圖）。
#
# - 使用 Inpaint 修補小細節：修正臉部瑕疵、背景中不自然的元素。
#
# - 使用 Canny 加強輪廓控制：確保人物的輪廓清晰、符合個人品牌框架。
#
# 3. **輸出與優化**：匯出 2~3 組備選圖像。比較主題一致性與辨識度。加入 logo、水印與統一邊框風格後使用於社群平台。
#
#
#
# ## Prompt
#
# 1.
# - prompt:
# portrait of a young Asian woman with short black hair, wearing a minimalist white blouse, soft lighting, digital art style, looking confident and friendly, centered composition, clean background
# - Style:
# Digital Illustration
# - Inpaint:
# 臉部輪廓細緻化 + 眼神方向微調
# - Canny:
# 加強頭髮與臉部輪廓銳利度
#
# 2.
# - prompt:
# illustration of a creative designer in workspace, minimalism background, warm tone, slight isometric perspective
# - Style:
# Flat Vector + Warm Color Palette
# - Inpaint:
# 移除雜物背景，專注於主角動作表現
# - Canny:
# 保留人物姿勢線條，簡化桌面雜訊
#
# 3.
# - prompt:
# headshot of a female tech entrepreneur, futuristic background with floating UI panels, semi-realistic style, glowing elements, sleek color palette
# - Style:
# Futuristic UI Portrait
# - Inpaint:
# 背景中 panel 排列重建 + 修補手部邊緣
# - Canny:
# 強化 UI panel 與主角的視覺層次
#
# ## 使用心得分享
# Fooocus 的流程相當直觀，尤其在試圖控制構圖或角色細節時，Inpaint 與 Canny 的組合非常實用。
#
# 相較 Midjourney，Fooocus 更適合需要針對小細節微調的任務。
#
# 搭配 UI 模板與品牌識別元件後，可以快速生成一整套符合品牌視覺的圖像。
#
# 建議一次輸出多張圖片，從中挑選最具一致性的一組，有助於後續的品牌視覺延伸。

# %%
# !pip install pygit2==1.15.1
# %cd /content
# !git clone https://github.com/lllyasviel/Fooocus.git
# %cd /content/Fooocus
# !python entry_with_update.py --share --always-high-vram
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 50.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pygit2
#     Found existing installation: pygit2 1.18.0
#     Uninstalling pygit2-1.18.0:
#       Successfully uninstalled pygit2-1.18.0
# ...
# /content
# Cloning into 'Fooocus'...
# remote: Enumerating objects: 6725, done.
# remote: Total 6725 (delta 0), reused 0 (delta 0), pack-reused 6725 (from 1)
# Receiving objects: 100% (6725/6725), 33.33 MiB | 32.94 MiB/s, done.
# Resolving deltas: 100% (3856/3856), done.
# /content/Fooocus
# Already up-to-date
# Update succeeded.
# [System ARGV] ['entry_with_update.py', '--share', '--always-high-vram']
# Python 3.11.12 (main, Apr  9 2025, 08:55:54) [GCC 11.4.0]
# Fooocus version: 2.5.5
# Error checking version for torchsde: No package metadata was found for torchsde
# Installing requirements
# [Cleanup] Attempting to delete content of temp dir /tmp/fooocus
# [Cleanup] Cleanup successful
# ...
